# %%
# !pip install llama-index --quiet
# !pip install llama-index-core --quiet
# !pip install llama-index-postprocessor-flag-embedding-reranker --quiet
# !pip install git+https://github.com/FlagOpen/FlagEmbedding.git --quiet
# !pip install llama-parse --quiet

# !pip install llama-index-embeddings-gemini -q
# !pip install llama-index-llms-gemini -q
# !pip install langchain -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.0 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# kfp 2.5.0 requires kubernetes<27,>=8.0.0, but you have kubernetes 29.0.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.8.1 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# jupyterlab 4.1.2 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.3 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
import pandas as pd

import gc
import torch
from llama_index.core import Settings
from llama_parse import LlamaParse
from llama_index.core import VectorStoreIndex
from llama_index.core.prompts import PromptTemplate

from llama_index.core.retrievers import RecursiveRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor

# %%
import nest_asyncio
nest_asyncio.apply()

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
GOOGLE_API_KEY = user_secrets.get_secret("GOOGLE_API_KEY")
LLAMA_CLOUD_API_KEY = user_secrets.get_secret("llama_cloud")

import os
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
data_dir = "/kaggle/input/unifi-data"

amkey_syn = pd.read_csv(f"{data_dir}/ActivityMetricsSynonyms.csv")
amkey_df = pd.read_csv(f"{data_dir}/AMKEY_GoldenStandard.csv")
sub_df = pd.read_csv(f"{data_dir}/SampleSubmission.csv")

# %%
import asyncio
from abc import abstractmethod
from typing import Any, Dict, List, Optional, Sequence, Tuple, cast

from tqdm import tqdm

from llama_index.core.async_utils import DEFAULT_NUM_WORKERS, run_jobs
from llama_index.core.base.response.schema import PydanticResponse
from llama_index.core.bridge.pydantic import BaseModel, Field, ValidationError
from llama_index.core.callbacks.base import CallbackManager
from llama_index.core.llms.llm import LLM
from llama_index.core.node_parser.interface import NodeParser
from llama_index.core.schema import BaseNode, Document, IndexNode, TextNode
from llama_index.core.utils import get_tqdm_iterable

DEFAULT_SUMMARY_QUERY_STR = """print NO INPUT"""

class TableColumnOutput(BaseModel):
    """Output from analyzing a table column."""

    col_name: str
    col_type: str
    summary: Optional[str] = None

    def __str__(self) -> str:
        """Convert to string representation."""
        return (
            f"Column: {self.col_name}\nType: {self.col_type}\nSummary: {self.summary}"
        )


class TableOutput(BaseModel):
    """Output from analyzing a table."""

    summary: str
    table_title: Optional[str] = None
    table_id: Optional[str] = None
    columns: List[TableColumnOutput]


class Element(BaseModel):
    """Element object."""

    id: str
    type: str
    element: Any
    title_level: Optional[int] = None
    table_output: Optional[TableOutput] = None
    table: Optional[pd.DataFrame] = None

    class Config:
        arbitrary_types_allowed = True


class BaseElementNodeParser(NodeParser):
    """
    Splits a document into Text Nodes and Index Nodes corresponding to embedded objects.

    Supports text and tables currently.
    """

    callback_manager: CallbackManager = Field(
        default_factory=CallbackManager, exclude=True
    )
    llm: Optional[LLM] = Field(
        default=None, description="LLM model to use for summarization."
    )
    summary_query_str: str = Field(
        default=DEFAULT_SUMMARY_QUERY_STR,
        description="Query string to use for summarization.",
    )
    num_workers: int = Field(
        default=DEFAULT_NUM_WORKERS,
        description="Num of works for async jobs.",
    )

    show_progress: bool = Field(default=True, description="Whether to show progress.")

    @classmethod
    def class_name(cls) -> str:
        return "BaseStructuredNodeParser"

    @classmethod
    def from_defaults(
        cls,
        callback_manager: Optional[CallbackManager] = None,
        **kwargs: Any,
    ) -> "BaseElementNodeParser":
        callback_manager = callback_manager or CallbackManager([])

        return cls(
            callback_manager=callback_manager,
            **kwargs,
        )

    def _parse_nodes(
        self,
        nodes: Sequence[BaseNode],
        show_progress: bool = False,
        **kwargs: Any,
    ) -> List[BaseNode]:
        all_nodes: List[BaseNode] = []
        nodes_with_progress = get_tqdm_iterable(nodes, show_progress, "Parsing nodes")

        for node in nodes_with_progress:
            nodes = self.get_nodes_from_node(node)
            all_nodes.extend(nodes)

        return all_nodes

    @abstractmethod
    def get_nodes_from_node(self, node: TextNode) -> List[BaseNode]:
        """Get nodes from node."""

    @abstractmethod
    def extract_elements(self, text: str, **kwargs: Any) -> List[Element]:
        """Extract elements from text."""

    def get_table_elements(self, elements: List[Element]) -> List[Element]:
        """Get table elements."""
        return [e for e in elements if e.type == "table" or e.type == "table_text"]

    def get_text_elements(self, elements: List[Element]) -> List[Element]:
        """Get text elements."""
        # TODO: There we should maybe do something with titles
        # and other elements in the future?
        return [e for e in elements if e.type != "table"]

    def extract_table_summaries(self, elements: List[Element]) -> None:
        """Go through elements, extract out summaries that are tables."""
        from llama_index.core.indices.list.base import SummaryIndex
        from llama_index.core.service_context import ServiceContext

        llm = self.llm
        ## Changes
#         if self.llm:
#             llm = self.llm
#         else:
#             try:
#                 from llama_index.llms.openai import OpenAI  # pants: no-infer-dep
#             except ImportError as e:
#                 raise ImportError(
#                     "`llama-index-llms-openai` package not found."
#                     " Please install with `pip install llama-index-llms-openai`."
#                 )
#             llm = OpenAI()
        llm = cast(LLM, llm)

        service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)

        table_context_list = []
        for idx, element in tqdm(enumerate(elements)):
            if element.type not in ("table", "table_text"):
                continue
            table_context = str(element.element)
            if idx > 0 and str(elements[idx - 1].element).lower().strip().startswith(
                "table"
            ):
                table_context = str(elements[idx - 1].element) + "\n" + table_context
            if idx < len(elements) + 1 and str(
                elements[idx - 1].element
            ).lower().strip().startswith("table"):
                table_context += "\n" + str(elements[idx + 1].element)

            table_context_list.append(table_context)

        ## Changes
        async def _get_table_output(table_context: str, summary_query_str: str) -> Any:
#             index = SummaryIndex.from_documents(
#                 [Document(text=table_context)], service_context=service_context
#             )
#             query_engine = index.as_query_engine(llm=llm, output_cls=TableOutput)
#             try:
#                 response = await query_engine.aquery(summary_query_str)
#                 return cast(PydanticResponse, response).response
#             except ValidationError:
#                 # There was a pydantic validation error, so we will run with text completion
#                 # fill in the summary and leave other fields blank
#                 query_engine = index.as_query_engine()
#                 response_txt = await query_engine.aquery(summary_query_str)
            return TableOutput(summary=str(table_context), columns=[])

        summary_jobs = [
            _get_table_output(table_context, self.summary_query_str)
            for table_context in table_context_list
        ]
        summary_outputs = asyncio.run(
            run_jobs(
                summary_jobs, show_progress=self.show_progress, workers=self.num_workers
            )
        )
        for element, summary_output in zip(elements, summary_outputs):
            element.table_output = summary_output

    def get_base_nodes_and_mappings(
        self, nodes: List[BaseNode]
    ) -> Tuple[List[BaseNode], Dict]:
        """Get base nodes and mappings.

        Given a list of nodes and IndexNode objects, return the base nodes and a mapping
        from index id to child nodes (which are excluded from the base nodes).

        """
        node_dict = {node.node_id: node for node in nodes}

        node_mappings = {}
        base_nodes = []

        # first map index nodes to their child nodes
        nonbase_node_ids = set()
        for node in nodes:
            if isinstance(node, IndexNode):
                node_mappings[node.index_id] = node_dict[node.index_id]
                nonbase_node_ids.add(node.index_id)
            else:
                pass

        # then add all nodes that are not children of index nodes
        for node in nodes:
            if node.node_id not in nonbase_node_ids:
                base_nodes.append(node)

        return base_nodes, node_mappings

    def get_nodes_and_objects(
        self, nodes: List[BaseNode]
    ) -> Tuple[List[BaseNode], List[IndexNode]]:
        base_nodes, node_mappings = self.get_base_nodes_and_mappings(nodes)

        nodes = []
        objects = []
        for node in base_nodes:
            if isinstance(node, IndexNode):
                node.obj = node_mappings[node.index_id]
                objects.append(node)
            else:
                nodes.append(node)

        return nodes, objects

    def _get_nodes_from_buffer(
        self, buffer: List[str], node_parser: NodeParser
    ) -> List[BaseNode]:
        """Get nodes from buffer."""
        doc = Document(text="\n\n".join(list(buffer)))
        return node_parser.get_nodes_from_documents([doc])

    def get_nodes_from_elements(self, elements: List[Element]) -> List[BaseNode]:
        """Get nodes and mappings."""
        from llama_index.core.node_parser import SentenceSplitter

        node_parser = SentenceSplitter()

        nodes = []
        cur_text_el_buffer: List[str] = []
        for element in elements:
            if element.type == "table" or element.type == "table_text":
                # flush text buffer for table
                if len(cur_text_el_buffer) > 0:
                    cur_text_nodes = self._get_nodes_from_buffer(
                        cur_text_el_buffer, node_parser
                    )
                    nodes.extend(cur_text_nodes)
                    cur_text_el_buffer = []

                table_output = cast(TableOutput, element.table_output)
                table_md = ""
                if element.type == "table":
                    table_df = cast(pd.DataFrame, element.table)
                    # We serialize the table as markdown as it allow better accuracy
                    # We do not use the table_df.to_markdown() method as it generate
                    # a table with a token hungry format.
                    table_md = "|"
                    for col_name, col in table_df.items():
                        table_md += f"{col_name}|"
                    table_md += "\n|"
                    for col_name, col in table_df.items():
                        table_md += f"---|"
                    table_md += "\n"
                    for row in table_df.itertuples():
                        table_md += "|"
                        for col in row[1:]:
                            table_md += f"{col}|"
                        table_md += "\n"
                elif element.type == "table_text":
                    # if the table is non-perfect table, we still want to keep the original text of table
                    table_md = str(element.element)
                table_id = element.id + "_table"
                table_ref_id = element.id + "_table_ref"

                col_schema = "\n\n".join([str(col) for col in table_output.columns])

                # We build a summary of the table containing the extracted summary, and a description of the columns
                table_summary = str(table_output.summary)
                if table_output.table_title:
                    table_summary += ",\nwith the following table title:\n"
                    table_summary += str(table_output.table_title)

                table_summary += ",\nwith the following columns:\n"

                for col in table_output.columns:
                    table_summary += f"- {col.col_name}: {col.summary}\n"

                index_node = IndexNode(
                    text=table_summary,
                    metadata={"col_schema": col_schema},
                    excluded_embed_metadata_keys=["col_schema"],
                    id_=table_ref_id,
                    index_id=table_id,
                )

                table_str = table_summary + "\n" + table_md

                text_node = TextNode(
                    text=table_str,
                    id_=table_id,
                    metadata={
                        # serialize the table as a dictionary string for dataframe of perfect table
                        "table_df": (
                            str(table_df.to_dict())
                            if element.type == "table"
                            else table_md
                        ),
                        # add table summary for retrieval purposes
                        "table_summary": table_summary,
                    },
                    excluded_embed_metadata_keys=["table_df", "table_summary"],
                    excluded_llm_metadata_keys=["table_df", "table_summary"],
                )
                nodes.extend([index_node, text_node])
            else:
                cur_text_el_buffer.append(str(element.element))
        # flush text buffer
        if len(cur_text_el_buffer) > 0:
            cur_text_nodes = self._get_nodes_from_buffer(
                cur_text_el_buffer, node_parser
            )
            nodes.extend(cur_text_nodes)
            cur_text_el_buffer = []

        # remove empty nodes
        return [node for node in nodes if len(node.text) > 0]

# %%
from io import StringIO
from typing import Any, Callable, List, Optional

import pandas as pd
from llama_index.core.node_parser.relational.base_element import (
#     BaseElementNodeParser,
    Element,
)
from llama_index.core.schema import BaseNode, TextNode


def md_to_df(md_str: str) -> pd.DataFrame:
    """Convert Markdown to dataframe."""
    # Replace " by "" in md_str
    md_str = md_str.replace('"', '""')

    # Replace markdown pipe tables with commas
    md_str = md_str.replace("|", '","')

    # Remove the second line (table header separator)
    lines = md_str.split("\n")
    md_str = "\n".join(lines[:1] + lines[2:])

    # Remove the first and last second char of the line (the pipes, transformed to ",")
    lines = md_str.split("\n")
    md_str = "\n".join([line[2:-2] for line in lines])

    # Check if the table is empty
    if len(md_str) == 0:
        return None

    # Use pandas to read the CSV string into a DataFrame
    return pd.read_csv(StringIO(md_str))


class MarkdownElementNodeParser(BaseElementNodeParser):
    """Markdown element node parser.

    Splits a markdown document into Text Nodes and Index Nodes corresponding to embedded objects
    (e.g. tables).

    """

    @classmethod
    def class_name(cls) -> str:
        return "MarkdownElementNodeParser"

    def get_nodes_from_node(self, node: TextNode) -> List[BaseNode]:
        """Get nodes from node."""
        elements = self.extract_elements(
            node.get_content(),
            table_filters=[self.filter_table],
            node_id=node.id_,
        )
        table_elements = self.get_table_elements(elements)
        # extract summaries over table elements
        self.extract_table_summaries(table_elements)
        # convert into nodes
        # will return a list of Nodes and Index Nodes
        return self.get_nodes_from_elements(elements)

    def extract_elements(
        self,
        text: str,
        node_id: Optional[str] = None,
        table_filters: Optional[List[Callable]] = None,
        **kwargs: Any,
    ) -> List[Element]:
        # get node id for each node so that we can avoid using the same id for different nodes
        """Extract elements from text."""
        lines = text.split("\n")
        currentElement = None

        elements: List[Element] = []
        # Then parse the lines
        for line in lines:
            if line.startswith("```"):
                # check if this is the end of a code block
                if currentElement is not None and currentElement.type == "code":
                    elements.append(currentElement)
                    currentElement = None
                    # if there is some text after the ``` create a text element with it
                    if len(line) > 3:
                        elements.append(
                            Element(
                                id=f"id_{len(elements)}",
                                type="text",
                                element=line.lstrip("```"),
                            )
                        )

                elif line.count("```") == 2 and line[-3] != "`":
                    # check if inline code block (aka have a second ``` in line but not at the end)
                    if currentElement is not None:
                        elements.append(currentElement)
                    currentElement = Element(
                        id=f"id_{len(elements)}",
                        type="code",
                        element=line.lstrip("```"),
                    )
                elif currentElement is not None and currentElement.type == "text":
                    currentElement.element += "\n" + line
                else:
                    if currentElement is not None:
                        elements.append(currentElement)
                    currentElement = Element(
                        id=f"id_{len(elements)}", type="text", element=line
                    )

            elif currentElement is not None and currentElement.type == "code":
                currentElement.element += "\n" + line

            elif line.startswith("|"):
                if currentElement is not None and currentElement.type != "table":
                    if currentElement is not None:
                        elements.append(currentElement)
                    currentElement = Element(
                        id=f"id_{len(elements)}", type="table", element=line
                    )
                elif currentElement is not None:
                    currentElement.element += "\n" + line
                else:
                    currentElement = Element(
                        id=f"id_{len(elements)}", type="table", element=line
                    )
            elif line.startswith("#"):
                if currentElement is not None:
                    elements.append(currentElement)
                currentElement = Element(
                    id=f"id_{len(elements)}",
                    type="title",
                    element=line.lstrip("#"),
                    title_level=len(line) - len(line.lstrip("#")),
                )
            else:
                if currentElement is not None and currentElement.type != "text":
                    elements.append(currentElement)
                    currentElement = Element(
                        id=f"id_{len(elements)}", type="text", element=line
                    )
                elif currentElement is not None:
                    currentElement.element += "\n" + line
                else:
                    currentElement = Element(
                        id=f"id_{len(elements)}", type="text", element=line
                    )
        if currentElement is not None:
            elements.append(currentElement)

        for idx, element in enumerate(elements):
            if element.type == "table":
                should_keep = True
                perfect_table = True

                # verify that the table (markdown) have the same number of columns on each rows
                table_lines = element.element.split("\n")
                table_columns = [len(line.split("|")) for line in table_lines]
                if len(set(table_columns)) > 1:
                    # if the table have different number of columns on each rows, it's not a perfect table
                    # we will store the raw text for such tables instead of converting them to a dataframe
                    perfect_table = False

                # verify that the table (markdown) have at least 2 rows
                if len(table_lines) < 2:
                    should_keep = False

                # apply the table filter, now only filter empty tables
                if should_keep and perfect_table and table_filters is not None:
                    should_keep = all(tf(element) for tf in table_filters)

                # if the element is a table, convert it to a dataframe
                if should_keep:
                    if perfect_table:
                        table = md_to_df(element.element)

                        elements[idx] = Element(
                            id=f"id_{node_id}_{idx}" if node_id else f"id_{idx}",
                            type="table",
                            element=element,
                            table=table,
                        )
                    else:
                        # for non-perfect tables, we will store the raw text
                        # and give it a different type to differentiate it from perfect tables
                        elements[idx] = Element(
                            id=f"id_{node_id}_{idx}" if node_id else f"id_{idx}",
                            type="table_text",
                            element=element.element,
                            # table=table
                        )
                else:
                    elements[idx] = Element(
                        id=f"id_{node_id}_{idx}" if node_id else f"id_{idx}",
                        type="text",
                        element=element.element,
                    )
            else:
                # if the element is not a table, keep it as to text
                elements[idx] = Element(
                    id=f"id_{node_id}_{idx}" if node_id else f"id_{idx}",
                    type="text",
                    element=element.element,
                )

        # merge consecutive text elements together for now
        merged_elements: List[Element] = []
        for element in elements:
            if (
                len(merged_elements) > 0
                and element.type == "text"
                and merged_elements[-1].type == "text"
            ):
                merged_elements[-1].element += "\n" + element.element
            else:
                merged_elements.append(element)
        elements = merged_elements
        return merged_elements

    def filter_table(self, table_element: Any) -> bool:
        """Filter tables."""
        table_df = md_to_df(table_element.element)

        # check if table_df is not None, has more than one row, and more than one column
        return table_df is not None and not table_df.empty and len(table_df.columns) > 1

# %%
from llama_index.llms.gemini import Gemini
from llama_index.embeddings.gemini import GeminiEmbedding
from google.generativeai.types.safety_types import HarmBlockThreshold, HarmCategory

safety_settings = {
HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,

}

Settings.embed_model = GeminiEmbedding(model_name="models/embedding-001")
Settings.llm = Gemini(model="models/gemini-pro",
                             temperature=0.0,
                             safety_settings=safety_settings,
                             )

Settings.chunk_size = 200
Settings.chunk_overlap = 20

# %%
big_dict = {
    "Absa": {"path": f"{data_dir}/Absa.pdf","retriever": None},
    "Clicks": {"path": f"{data_dir}/Clicks.pdf","retriever": None},
    "Distell": {"path": f"{data_dir}/Distell.pdf","retriever": None},
    "Oceana1&2": {"path": [f"{data_dir}/Oceana1.pdf",f"{data_dir}/Oceana2.pdf"],"retriever": None}, 
    "Ssw": {"path": f"{data_dir}/Ssw.pdf","retriever": None},
    "Picknpay": {"path": f"{data_dir}/Picknpay.pdf","retriever": None},
    "Sasol": {"path": f"{data_dir}/Sasol.pdf","retriever": None},
    "Impala": {"path": f"{data_dir}/Impala.pdf","retriever": None},
}

# %%
parser = LlamaParse(
        result_type="markdown",  # "markdown" and "text" are available
        num_workers=4, # if multiple files passed, split in `num_workers` API calls
        api_key=LLAMA_CLOUD_API_KEY
    )

node_parser = MarkdownElementNodeParser(llm = None, num_workers=8)

for group, _ in big_dict.items():
    print(group)
    documents = parser.load_data(big_dict[group]['path'])

    ## NODES
    nodes = node_parser.get_nodes_from_documents(documents)

    ## nodes and mappings
    base_nodes, node_mappings = node_parser.get_base_nodes_and_mappings(nodes)

    index = VectorStoreIndex(nodes=base_nodes)
    index_ret = index.as_retriever(top_k=5)

    ## recursive query engine
    recursive_index = RecursiveRetriever(
        "vector",
        retriever_dict={"vector": index_ret},
        node_dict=node_mappings,
        verbose=False,
    )
    
    big_dict[group]['retriever'] = recursive_index
    
    del documents, nodes, base_nodes, node_mappings, index, index_ret, recursive_index
    gc.collect()
# Out:
# Absa
# Started parsing the file under job_id dcceb915-a5c9-42c5-a60e-eb0ca356d48c
# ...............................................................
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 46it [00:00, 11943.67it/s]
# 100%|██████████| 46/46 [00:00<00:00, 16173.86it/s]
# Clicks
# Started parsing the file under job_id 2e5cbb2c-4177-4b54-b8e2-066103dc7147
# ..
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 31it [00:00, 11728.61it/s]
# 100%|██████████| 31/31 [00:00<00:00, 9799.04it/s]
# Distell
# Started parsing the file under job_id 6dd4f65e-14c1-48bb-8e65-7e873bdf1375
# ..
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 22it [00:00, 10390.12it/s]
# 100%|██████████| 22/22 [00:00<00:00, 14366.29it/s]
# Oceana1&2
# Started parsing the file under job_id 7724d73a-b8ab-4e76-8c39-136ff8ef08e9
# Started parsing the file under job_id e3d7ba7a-25e5-43bb-acef-3d9f334dac38
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 56it [00:00, 14408.11it/s]
# 100%|██████████| 56/56 [00:00<00:00, 11715.35it/s]
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 14it [00:00, 35416.32it/s]
# 100%|██████████| 14/14 [00:00<00:00, 9419.35it/s]
# Ssw
# Started parsing the file under job_id 0a9466e9-e44a-4507-9b5a-084f0ed08975
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 363it [00:00, 18941.21it/s]
# 100%|██████████| 363/363 [00:00<00:00, 16903.88it/s]
# Picknpay
# Started parsing the file under job_id 7698065c-b17f-4fe3-8fb5-e36afb9df17c
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 25it [00:00, 9189.97it/s]
# 100%|██████████| 25/25 [00:00<00:00, 14048.45it/s]
# Sasol
# Started parsing the file under job_id daf2be7c-acd8-411b-a5fd-3c73927f430e
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 85it [00:00, 18606.33it/s]
# 100%|██████████| 85/85 [00:00<00:00, 17333.52it/s]
# Impala
# Started parsing the file under job_id 5e6a3fbb-2268-4316-a6eb-5eac17b68965
# /tmp/ipykernel_18/2885970483.py:149: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm, embed_model=None)
# LLM is explicitly disabled. Using MockLLM.
# Embeddings have been explicitly disabled. Using MockEmbedding.
# 81it [00:00, 20024.67it/s]
# 100%|██████████| 81/81 [00:00<00:00, 16380.84it/s]

# %%
qa_prompt = """Retrieve and present accurate factual numeric value.
Very Important Rules to remember before answering:
1. Output should be integer or float value only, no alphabets or symbols are allowed.
2. False positives can cause big loss, so if you don't find exact Input in the context, then just return 0.0 float value.
4. Data should be from 2022 annual reports only.

Here is the context: {context_str}
Input: {query_str}"""

qa_template = PromptTemplate(qa_prompt)

# %%
with_2022_data = ["Absa",
        "Clicks",
        "Distell",
        "Oceana1&2",
        "Ssw",
        "Picknpay",
        "Sasol",
        "Impala"]

# %%
import time

def generate(id_):
    amkey, group = id_.split("_X_")
    print(f'Group: {group}')
    try:
        question = amkey_syn[(amkey_syn["AMKEY"]==int(amkey)) & (amkey_syn["Group"]==group)]['ClientMetric'].values[0]
    except:
        question = amkey_df[amkey_df["AMKEY"]==int(amkey)]["ActivityMetric"].values[0]

    print(f'Question: {question}\n')

    if group not in with_2022_data:
        return 0.0

    recursive_index = big_dict[group]["retriever"]
    recursive_query_engine = RetrieverQueryEngine.from_args(recursive_index,
                                                            verbose=False)

    recursive_query_engine.update_prompts(
        {"response_synthesizer:text_qa_template": qa_template}
        )
    
    while True:
        try:
            
            result = recursive_query_engine.query(question)
            response = result.response
            break
        except Exception as e:
            print(f"Error: {e}")

    return response

# %%
def clean_output(text):
    try:
        return float(text)
    
    except:
        text = text.replace(" ","").replace(",","")
        return float(text)

# %%
import time
for i, id_ in enumerate(sub_df.ID):
    result = generate(id_)
    print(f'idx: {i} ---- value: {result}')
    sub_df.loc[i, "2022_Value"] = clean_output(result)
# Out:
# Group: Absa
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 0 ---- value: 0.0
# Group: Clicks
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 1 ---- value: 0.0
# Group: Distell
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 2 ---- value: 0.0
# Group: Impala
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 3 ---- value: 0.0
# Group: Oceana1&2
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 4 ---- value: 0.0
# Group: Picknpay
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 5 ---- value: 0.0
# Group: Sasol
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 6 ---- value: 0.0
# Group: Ssw
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 7 ---- value: 0.0
# Group: Tongaat
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 8 ---- value: 0.0
# Group: Uct1&2
# Question: Discussion of strategies to reduce the environmental impact of packaging
#
# idx: 9 ---- value: 0.0
# Group: Absa
# Question: Duration of strikes and lockouts
#
# idx: 10 ---- value: 0.0
# Group: Clicks
# Question: Duration of strikes and lockouts
#
# idx: 11 ---- value: 0.0
# Group: Distell
# Question: Duration of strikes and lockouts
#
# idx: 12 ---- value: 0.0
# Group: Impala
# Question: Duration of strikes and lockouts
#
# idx: 13 ---- value: 0.0
# Group: Oceana1&2
# Question: Duration of strikes and lockouts
#
# idx: 14 ---- value: 0.0
# Group: Picknpay
# Question: Duration of strikes and lockouts
#
# idx: 15 ---- value: 0.0
# Group: Sasol
# Question: Duration of strikes and lockouts
#
# idx: 16 ---- value: 0.0
# Group: Ssw
# Question: Duration of strikes and lockouts
#
# idx: 17 ---- value: 0.0
# Group: Tongaat
# Question: Duration of strikes and lockouts
#
# idx: 18 ---- value: 0.0
# Group: Uct1&2
# Question: Duration of strikes and lockouts
#
# idx: 19 ---- value: 0.0
# Group: Absa
# Question: Number of permanent employees (South African-based)
#
# idx: 20 ---- value: 0.0
# Group: Clicks
# Question: Number of permanent employees (South African-based)
#
# idx: 21 ---- value: 15646
# Group: Distell
# Question: Number of permanent employees (South African-based)
#
# idx: 22 ---- value: 0.0
# Group: Impala
# Question: Number of permanent employees (South African-based)
#
# idx: 23 ---- value: 0.0
# Group: Oceana1&2
# Question: Number of permanent employees (South African-based)
#
# idx: 24 ---- value: 0.0
# Group: Picknpay
# Question: Number of permanent employees (South African-based)
#
# idx: 25 ---- value: 0.0
# Group: Sasol
# Question: Number of permanent employees (South African-based)
#
# idx: 26 ---- value: 0.0
# Group: Ssw
# Question: Number of permanent employees (South African-based)
#
# idx: 27 ---- value: 0.0
# Group: Tongaat
# Question: Number of permanent employees (South African-based)
#
# idx: 28 ---- value: 0.0
# Group: Uct1&2
# Question: Number of permanent employees (South African-based)
#
# idx: 29 ---- value: 0.0
# Group: Absa
# Question: Female employees technically-skilled
#
# idx: 30 ---- value: 0.0
# Group: Clicks
# Question: Female employees technically-skilled
#
# idx: 31 ---- value: 0.0
# Group: Distell
# Question: Female employees technically-skilled
#
# idx: 32 ---- value: 0.0
# Group: Impala
# Question: Female employees technically-skilled
#
# idx: 33 ---- value: 0.0
# Group: Oceana1&2
# Question: Female employees technically-skilled
#
# idx: 34 ---- value: 0.0
# Group: Picknpay
# Question: Female employees technically-skilled
#
# idx: 35 ---- value: 0.0
# Group: Sasol
# Question: Female employees technically-skilled
#
# idx: 36 ---- value: 0.0
# Group: Ssw
# Question: Female employees technically-skilled
#
# idx: 37 ---- value: 0.0
# Group: Tongaat
# Question: Female employees technically-skilled
#
# idx: 38 ---- value: 0.0
# Group: Uct1&2
# Question: Female employees technically-skilled
#
# idx: 39 ---- value: 0.0
# Group: Absa
# Question: Female employees semi-skilled
#
# idx: 40 ---- value: 0.0
# Group: Clicks
# Question: Female employees semi-skilled
#
# idx: 41 ---- value: 0.0
# Group: Distell
# Question: Female employees semi-skilled
#
# idx: 42 ---- value: 0.0
# Group: Impala
# Question: Female employees semi-skilled
#
# idx: 43 ---- value: 0.0
# Group: Oceana1&2
# Question: Female employees semi-skilled
#
# idx: 44 ---- value: 0.0
# Group: Picknpay
# Question: Female employees semi-skilled
#
# idx: 45 ---- value: 0.0
# Group: Sasol
# Question: Female employees semi-skilled
#
# idx: 46 ---- value: 0.0
# Group: Ssw
# Question: Female employees semi-skilled
#
# idx: 47 ---- value: 0.0
# Group: Tongaat
# Question: Female employees semi-skilled
#
# idx: 48 ---- value: 0.0
# Group: Uct1&2
# Question: Female employees semi-skilled
#
# idx: 49 ---- value: 0.0
# Group: Absa
# Question: Black employees trained
#
# idx: 50 ---- value: 0.0
# Group: Clicks
# Question: Black employees trained
#
# idx: 51 ---- value: 0.0
# Group: Distell
# Question: Black employees trained
#
# idx: 52 ---- value: 0.0
# Group: Impala
# Question: Black employees trained
#
# idx: 53 ---- value: 0.0
# Group: Oceana1&2
# Question: Black employees trained
#
# idx: 54 ---- value: 0.0
# Group: Picknpay
# Question: Black employees trained
#
# idx: 55 ---- value: 0.0
# Group: Sasol
# Question: Black employees trained
#
# idx: 56 ---- value: 0.0
# Group: Ssw
# Question: Black employees trained
#
# idx: 57 ---- value: 0.0
# Group: Tongaat
# Question: Black employees trained
#
# idx: 58 ---- value: 0.0
# Group: Uct1&2
# Question: Black employees trained
#
# idx: 59 ---- value: 0.0
# Group: Absa
# Question: Female employees trained
#
# idx: 60 ---- value: 0.0
# Group: Clicks
# Question: Female employees trained
#
# idx: 61 ---- value: 0.0
# Group: Distell
# Question: Female employees trained
#
# idx: 62 ---- value: 0.0
# Group: Impala
# Question: Female employees trained
#
# idx: 63 ---- value: 0.0
# Group: Oceana1&2
# Question: Female employees trained
#
# idx: 64 ---- value: 0.0
# Group: Picknpay
# Question: Female employees trained
#
# idx: 65 ---- value: 0.0
# Group: Sasol
# Question: Female employees trained
#
# idx: 66 ---- value: 0.0
# Group: Ssw
# Question: Female employees trained
#
# idx: 67 ---- value: 0.0
# Group: Tongaat
# Question: Female employees trained
#
# idx: 68 ---- value: 0.0
# Group: Uct1&2
# Question: Female employees trained
#
# idx: 69 ---- value: 0.0
# Group: Absa
# Question: Economic interest (% ownership) of black people
#
# idx: 70 ---- value: 0.0
# Group: Clicks
# Question: Economic interest (% ownership) of black people
#
# idx: 71 ---- value: 0.0
# Group: Distell
# Question: Economic interest (% ownership) of black people
#
# idx: 72 ---- value: 0.0
# Group: Impala
# Question: Economic interest (% ownership) of black people
#
# idx: 73 ---- value: 0.0
# Group: Oceana1&2
# Question: Economic interest (% ownership) of black people
#
# idx: 74 ---- value: 0.0
# Group: Picknpay
# Question: Economic interest (% ownership) of black people
#
# idx: 75 ---- value: 0.0
# Group: Sasol
# Question: Economic interest (% ownership) of black people
#
# idx: 76 ---- value: 0.0
# Group: Ssw
# Question: Economic interest (% ownership) of black people
#
# idx: 77 ---- value: 0.0
# Group: Tongaat
# Question: Economic interest (% ownership) of black people
#
# idx: 78 ---- value: 0.0
# Group: Uct1&2
# Question: Economic interest (% ownership) of black people
#
# idx: 79 ---- value: 0.0
# Group: Absa
# Question: Lost days
#
# idx: 80 ---- value: 0.0
# Group: Clicks
# Question: Lost days
#
# idx: 81 ---- value: 0.0
# Group: Distell
# Question: Number of lost days (Distell Group)
#
# idx: 82 ---- value: 0.0
# Group: Impala
# Question: Lost days
#
# idx: 83 ---- value: 0.0
# Group: Oceana1&2
# Question: Lost days
#
# idx: 84 ---- value: 0.0
# Group: Picknpay
# Question: Lost days
#
# idx: 85 ---- value: 0.0
# Group: Sasol
# Question: Lost days
#
# idx: 86 ---- value: 0.0
# Group: Ssw
# Question: Lost days
#
# idx: 87 ---- value: 0.0
# Group: Tongaat
# Question: Lost days
#
# idx: 88 ---- value: 0.0
# Group: Uct1&2
# Question: Lost days
#
# idx: 89 ---- value: 0.0
# Group: Absa
# Question: Percentage of non-executive board members
#
# idx: 90 ---- value: 0.0
# Group: Clicks
# Question: Percentage of non-executive board members
#
# idx: 91 ---- value: 80
# Group: Distell
# Question: Percentage of board members who are deemed non-executive
#
# idx: 92 ---- value: 83.3
# Group: Impala
# Question: Percentage of non-executive board members
#
# idx: 93 ---- value: 0.0
# Group: Oceana1&2
# Question: Percentage of non-executive board members
#
# idx: 94 ---- value: 0.0
# Group: Picknpay
# Question: Percentage of non-executive board members
#
# idx: 95 ---- value: 0.0
# Group: Sasol
# Question: Percentage of non-executive board members
#
# idx: 96 ---- value: 0.0
# Group: Ssw
# Question: Percentage of non-executive board members
#
# idx: 97 ---- value: 0.0
# Group: Tongaat
# Question: Percentage of non-executive Board members
#
# idx: 98 ---- value: 0.0
# Group: Uct1&2
# Question: Percentage of non-executive board members
#
# idx: 99 ---- value: 0.0
# Group: Absa
# Question: Percentage of independent board members
#
# idx: 100 ---- value: 0.0
# Group: Clicks
# Question: Percentage of independent board members
#
# idx: 101 ---- value: 80
# Group: Distell
# Question: Percentage of board members who are deemed 'independent'
#
# idx: 102 ---- value: 66.7
# Group: Impala
# Question: Percentage of independent board members
#
# idx: 103 ---- value: 0.0
# Group: Oceana1&2
# Question: Percentage of independent board members
#
# idx: 104 ---- value: 0.0
# Group: Picknpay
# Question: Percentage of independent board members
#
# idx: 105 ---- value: 0.0
# Group: Sasol
# Question: Percentage of independent board members
#
# idx: 106 ---- value: 0.0
# Group: Ssw
# Question: Independent, non-executive directors
#
# idx: 107 ---- value: 0.0
# Group: Tongaat
# Question: Percentage of independent Board members
#
# idx: 108 ---- value: 0.0
# Group: Uct1&2
# Question: Percentage of independent board members
#
# idx: 109 ---- value: 0.0
# Group: Absa
# Question: First aid representatives
#
# idx: 110 ---- value: 0.0
# Group: Clicks
# Question: First aid representatives
#
# idx: 111 ---- value: 0.0
# Group: Distell
# Question: First aid representatives
#
# idx: 112 ---- value: 0.0
# Group: Impala
# Question: First aid representatives
#
# idx: 113 ---- value: 0.0
# Group: Oceana1&2
# Question: First aid representatives
#
# idx: 114 ---- value: 0.0
# Group: Picknpay
# Question: First aid representatives
#
# idx: 115 ---- value: 0.0
# Group: Sasol
# Question: First aid representatives
#
# idx: 116 ---- value: 0.0
# Group: Ssw
# Question: First aid representatives
#
# idx: 117 ---- value: 0.0
# Group: Tongaat
# Question: First aid representatives
#
# idx: 118 ---- value: 0.0
# Group: Uct1&2
# Question: First aid representatives
#
# idx: 119 ---- value: 0.0
# Group: Absa
# Question: Firefighters
#
# idx: 120 ---- value: 0.0
# Group: Clicks
# Question: Firefighters
#
# idx: 121 ---- value: 0.0
# Group: Distell
# Question: Firefighters
#
# idx: 122 ---- value: 0.0
# Group: Impala
# Question: Firefighters
#
# idx: 123 ---- value: 0.0
# Group: Oceana1&2
# Question: Firefighters
#
# idx: 124 ---- value: 0.0
# Group: Picknpay
# Question: Firefighters
#
# idx: 125 ---- value: 0.0
# Group: Sasol
# Question: Firefighters
#
# idx: 126 ---- value: 0.0
# Group: Ssw
# Question: Firefighters
#
# idx: 127 ---- value: 0.0
# Group: Tongaat
# Question: Firefighters
#
# idx: 128 ---- value: 0.0
# Group: Uct1&2
# Question: Firefighters
#
# idx: 129 ---- value: 0.0
# Group: Absa
# Question: Health and saferty committee members
#
# idx: 130 ---- value: 0.0
# Group: Clicks
# Question: Health and saferty committee members
#
# idx: 131 ---- value: 1009
# Group: Distell
# Question: Health and saferty committee members
#
# idx: 132 ---- value: 0.0
# Group: Impala
# Question: Health and saferty committee members
#
# idx: 133 ---- value: 0.0
# Group: Oceana1&2
# Question: Health and saferty committee members
#
# idx: 134 ---- value: 0.0
# Group: Picknpay
# Question: Health and saferty committee members
#
# idx: 135 ---- value: 0.0
# Group: Sasol
# Question: Health and saferty committee members
#
# idx: 136 ---- value: 0.0
# Group: Ssw
# Question: Health and saferty committee members
#
# idx: 137 ---- value: 0.0
# Group: Tongaat
# Question: Health and saferty committee members
#
# idx: 138 ---- value: 0.0
# Group: Uct1&2
# Question: Health and saferty committee members
#
# idx: 139 ---- value: 0.0
# Group: Absa
# Question: Store armed robbery incidents
#
# idx: 140 ---- value: 0.0
# Group: Clicks
# Question: Store armed robbery incidents
#
# idx: 141 ---- value: 0.0
# Group: Distell
# Question: Store armed robbery incidents
#
# idx: 142 ---- value: 0.0
# Group: Impala
# Question: Store armed robbery incidents
#
# idx: 143 ---- value: 0.0
# Group: Oceana1&2
# Question: Store armed robbery incidents
#
# idx: 144 ---- value: 0.0
# Group: Picknpay
# Question: Store armed robbery incidents
#
# idx: 145 ---- value: 0.0
# Group: Sasol
# Question: Store armed robbery incidents
#
# idx: 146 ---- value: 0.0
# Group: Ssw
# Question: Store armed robbery incidents
#
# idx: 147 ---- value: 0.0
# Group: Tongaat
# Question: Store armed robbery incidents
#
# idx: 148 ---- value: 0.0
# Group: Uct1&2
# Question: Store armed robbery incidents
#
# idx: 149 ---- value: 0.0
# Group: Absa
# Question: High risk cases
#
# idx: 150 ---- value: 0.0
# Group: Clicks
# Question: High risk cases
#
# idx: 151 ---- value: 0.0
# Group: Distell
# Question: High risk cases
#
# idx: 152 ---- value: 0.0
# Group: Impala
# Question: High risk cases
#
# idx: 153 ---- value: 0.0
# Group: Oceana1&2
# Question: High risk cases
#
# idx: 154 ---- value: 0.0
# Group: Picknpay
# Question: High risk cases
#
# idx: 155 ---- value: 0.0
# Group: Sasol
# Question: High risk cases
#
# idx: 156 ---- value: 0.0
# Group: Ssw
# Question: High risk cases
#
# idx: 157 ---- value: 0.0
# Group: Tongaat
# Question: High risk cases
#
# idx: 158 ---- value: 0.0
# Group: Uct1&2
# Question: High risk cases
#
# idx: 159 ---- value: 0.0
# Group: Absa
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 160 ---- value: 0.0
# Group: Clicks
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 161 ---- value: 0.0
# Group: Distell
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 162 ---- value: 0.0
# Group: Impala
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 163 ---- value: 0.0
# Group: Oceana1&2
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 164 ---- value: 0.0
# Group: Picknpay
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 165 ---- value: 0.0
# Group: Sasol
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 166 ---- value: 0.0
# Group: Ssw
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 167 ---- value: 0.0
# Group: Tongaat
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 168 ---- value: 0.0
# Group: Uct1&2
# Question: Group Employee Wellness Programme utilisation: Total utilisation rate
#
# idx: 169 ---- value: 0.0
# Group: Absa
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 170 ---- value: 0.0
# Group: Clicks
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 171 ---- value: 0.0
# Group: Distell
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 172 ---- value: 0.0
# Group: Impala
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 173 ---- value: 0.0
# Group: Oceana1&2
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 174 ---- value: 0.0
# Group: Picknpay
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 175 ---- value: 0.0
# Group: Sasol
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 176 ---- value: 0.0
# Group: Ssw
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 177 ---- value: 0.0
# Group: Tongaat
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 178 ---- value: 0.0
# Group: Uct1&2
# Question: Group Employee Wellness Programme utilisation: managerial services
#
# idx: 179 ---- value: 0.0
# Group: Absa
# Question: Economic interest (% ownership) of black women
#
# idx: 180 ---- value: 0.0
# Group: Clicks
# Question: Economic interest (% ownership) of black women
#
# idx: 181 ---- value: 0.0
# Group: Distell
# Question: Economic interest (% ownership) of black women
#
# idx: 182 ---- value: 0.0
# Group: Impala
# Question: Economic interest (% ownership) of black women
#
# idx: 183 ---- value: 0.0
# Group: Oceana1&2
# Question: Economic interest (% ownership) of black women
#
# idx: 184 ---- value: 0.0
# Group: Picknpay
# Question: Economic interest (% ownership) of black women
#
# idx: 185 ---- value: 0.0
# Group: Sasol
# Question: Economic interest (% ownership) of black women
#
# idx: 186 ---- value: 0.0
# Group: Ssw
# Question: Economic interest (% ownership) of black women
#
# idx: 187 ---- value: 0.0
# Group: Tongaat
# Question: Economic interest (% ownership) of black women
#
# idx: 188 ---- value: 0.0
# Group: Uct1&2
# Question: Economic interest (% ownership) of black women
#
# idx: 189 ---- value: 0.0
# Group: Absa
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 190 ---- value: 0.0
# Group: Clicks
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 191 ---- value: 0.0
# Group: Distell
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 192 ---- value: 0.0
# Group: Impala
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 193 ---- value: 0.0
# Group: Oceana1&2
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 194 ---- value: 0.0
# Group: Picknpay
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 195 ---- value: 0.0
# Group: Sasol
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 196 ---- value: 0.0
# Group: Ssw
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 197 ---- value: 0.0
# Group: Tongaat
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 198 ---- value: 0.0
# Group: Uct1&2
# Question: Group Employee Wellness Programme utilisation: managerial services (%)
#
# idx: 199 ---- value: 0.0
# Group: Absa
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 200 ---- value: 0.0
# Group: Clicks
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 201 ---- value: 0.0
# Group: Distell
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 202 ---- value: 0.0
# Group: Impala
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 203 ---- value: 0.0
# Group: Oceana1&2
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 204 ---- value: 0.0
# Group: Picknpay
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 205 ---- value: 0.0
# Group: Sasol
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 206 ---- value: 0.0
# Group: Ssw
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 207 ---- value: 0.0
# Group: Tongaat
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 208 ---- value: 0.0
# Group: Uct1&2
# Question: Total expenditure on ESD initiatives on Companies that have 51% or more black ownership
#
# idx: 209 ---- value: 0.0
# Group: Absa
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 210 ---- value: 0.0
# Group: Clicks
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 211 ---- value: 0.0
# Group: Distell
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 212 ---- value: 0.0
# Group: Impala
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 213 ---- value: 0.0
# Group: Oceana1&2
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 214 ---- value: 83.65
# Group: Picknpay
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 215 ---- value: 0.0
# Group: Sasol
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 216 ---- value: 0.0
# Group: Ssw
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 217 ---- value: 0.0
# Group: Tongaat
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 218 ---- value: 0.0
# Group: Uct1&2
# Question: Percentage of economic interest of  the  Black Natural Persons in the measured entity
#
# idx: 219 ---- value: 0.0
# Group: Absa
# Question: The net value of shares (as % of total net value)
#
# idx: 220 ---- value: 0.0
# Group: Clicks
# Question: The net value of shares (as % of total net value)
#
# idx: 221 ---- value: 0.0
# Group: Distell
# Question: The net value of shares (as % of total net value)
#
# idx: 222 ---- value: 0.0
# Group: Impala
# Question: The net value of shares (as % of total net value)
#
# idx: 223 ---- value: 0.0
# Group: Oceana1&2
# Question: The net value of shares (as % of total net value)
#
# idx: 224 ---- value: 0.0
# Group: Picknpay
# Question: The net value of shares (as % of total net value)
#
# idx: 225 ---- value: 0.0
# Group: Sasol
# Question: The net value of shares (as % of total net value)
#
# idx: 226 ---- value: 0.0
# Group: Ssw
# Question: The net value of shares (as % of total net value)
#
# idx: 227 ---- value: 0.0
# Group: Tongaat
# Question: The net value of shares (as % of total net value)
#
# idx: 228 ---- value: 0.0
# Group: Uct1&2
# Question: The net value of shares (as % of total net value)
#
# idx: 229 ---- value: 0.0
# Group: Absa
# Question: Black New Entrants
#
# idx: 230 ---- value: 0.0
# Group: Clicks
# Question: Black New Entrants
#
# idx: 231 ---- value: 0.0
# Group: Distell
# Question: Black New Entrants
#
# idx: 232 ---- value: 0.0
# Group: Impala
# Question: Black New Entrants
#
# idx: 233 ---- value: 0.0
# Group: Oceana1&2
# Question: Black New Entrants
#
# idx: 234 ---- value: 0.0
# Group: Picknpay
# Question: Black New Entrants
#
# idx: 235 ---- value: 0.0
# Group: Sasol
# Question: Black New Entrants
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 236 ---- value: 0.0
# Group: Ssw
# Question: Black New Entrants
#
# idx: 237 ---- value: 0.0
# Group: Tongaat
# Question: Black New Entrants
#
# idx: 238 ---- value: 0.0
# Group: Uct1&2
# Question: Black New Entrants
#
# idx: 239 ---- value: 0.0
# Group: Absa
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 240 ---- value: 0.0
# Group: Clicks
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 241 ---- value: 0.0
# Group: Distell
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 242 ---- value: 0.0
# Group: Impala
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 243 ---- value: 0.0
# Group: Oceana1&2
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 244 ---- value: 0.0
# Group: Picknpay
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 245 ---- value: 0.0
# Group: Sasol
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 246 ---- value: 0.0
# Group: Ssw
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 247 ---- value: 0.0
# Group: Tongaat
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 248 ---- value: 0.0
# Group: Uct1&2
# Question: Number of unemployed black people absorbed at the end of the leadership programme
#
# idx: 249 ---- value: 0.0
# Group: Absa
# Question: Emissions Reduction Strategy
#
# idx: 250 ---- value: 0.0
# Group: Clicks
# Question: Emissions Reduction Strategy
#
# idx: 251 ---- value: 0.0
# Group: Distell
# Question: Emissions Reduction Strategy
#
# idx: 252 ---- value: 0.0
# Group: Impala
# Question: Emissions Reduction Strategy
#
# idx: 253 ---- value: 0.0
# Group: Oceana1&2
# Question: Emissions Reduction Strategy
#
# idx: 254 ---- value: 0.0
# Group: Picknpay
# Question: Emissions Reduction Strategy
#
# idx: 255 ---- value: 0.0
# Group: Sasol
# Question: Emissions Reduction Strategy
#
# idx: 256 ---- value: 0.0
# Group: Ssw
# Question: Emissions Reduction Strategy
#
# idx: 257 ---- value: 0.0
# Group: Tongaat
# Question: Emissions Reduction Strategy
#
# idx: 258 ---- value: 0.0
# Group: Uct1&2
# Question: Emissions Reduction Strategy
#
# idx: 259 ---- value: 0.0
# Group: Absa
# Question: Fines associated with environmental incidents
#
# idx: 260 ---- value: 0.0
# Group: Clicks
# Question: Fines associated with environmental incidents
#
# idx: 261 ---- value: 0.0
# Group: Distell
# Question: Fines associated with environmental incidents
#
# idx: 262 ---- value: 0.0
# Group: Impala
# Question: Fines associated with environmental incidents
#
# idx: 263 ---- value: 0.0
# Group: Oceana1&2
# Question: Fines associated with environmental incidents
#
# idx: 264 ---- value: 0.0
# Group: Picknpay
# Question: Fines associated with environmental incidents
#
# idx: 265 ---- value: 0.0
# Group: Sasol
# Question: Fines associated with environmental incidents
#
# idx: 266 ---- value: 0.0
# Group: Ssw
# Question: Fines associated with environmental incidents
#
# idx: 267 ---- value: 0.0
# Group: Tongaat
# Question: Environmental fines and/or non-compliances
#
# idx: 268 ---- value: 0.0
# Group: Uct1&2
# Question: Fines associated with environmental incidents
#
# idx: 269 ---- value: 0.0
# Group: Absa
# Question: Staff costs and benefits (Rbn)
#
# idx: 270 ---- value: 27 873
# Group: Clicks
# Question: Employee wages and benefits
#
# idx: 271 ---- value: 0.0
# Group: Distell
# Question: Rand value of total compensation paid to employees, including wages and benefits in South Africa
#
# idx: 272 ---- value: 1.822391105
# Group: Impala
# Question: Employee wages and benefits
#
# idx: 273 ---- value: 0.0
# Group: Oceana1&2
# Question: Salaries and employee benefits
#
# idx: 274 ---- value: 0.0
# Group: Picknpay
# Question: Employee wages and benefits
#
# idx: 275 ---- value: 0.0
# Group: Sasol
# Question: Value added statement (unaudited) - Employees
#
# idx: 276 ---- value: 0.0
# Group: Ssw
# Question: Salaries and wages paid
#
# idx: 277 ---- value: 0.0
# Group: Tongaat
# Question: Employee wages and benefits
#
# idx: 278 ---- value: 0.0
# Group: Uct1&2
# Question: Personnel
#
# idx: 279 ---- value: 0.0
# Group: Absa
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 280 ---- value: 0.0
# Group: Clicks
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 281 ---- value: 0.0
# Group: Distell
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 282 ---- value: 0.0
# Group: Impala
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 283 ---- value: 0.0
# Group: Oceana1&2
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 284 ---- value: 0.0
# Group: Picknpay
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 285 ---- value: 0.0
# Group: Sasol
# Question: Volatile Organic Compounds (VOC) Indicator of Performance (kilotons)
#
# idx: 286 ---- value: 0.0
# Group: Ssw
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 287 ---- value: 0.0
# Group: Tongaat
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 288 ---- value: 0.0
# Group: Uct1&2
# Question: Air emissions of the following pollutants: (5)  volatile organic compounds (VOCs)
#
# idx: 289 ---- value: 0.0
# Group: Absa
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 290 ---- value: 0.0
# Group: Clicks
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 291 ---- value: 0.0
# Group: Distell
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 292 ---- value: 0.0
# Group: Impala
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 293 ---- value: 0.0
# Group: Oceana1&2
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 294 ---- value: 0.0
# Group: Picknpay
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 295 ---- value: 0.0
# Group: Sasol
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 296 ---- value: 0.0
# Group: Ssw
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 297 ---- value: 0.0
# Group: Tongaat
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 298 ---- value: 0.0
# Group: Uct1&2
# Question: Employee wages and benefits as a proportion of revenue
#
# idx: 299 ---- value: 0.0
# Group: Absa
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 300 ---- value: 0.0
# Group: Clicks
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 301 ---- value: 0.0
# Group: Distell
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 302 ---- value: 0.0
# Group: Impala
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 303 ---- value: 0.0
# Group: Oceana1&2
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 304 ---- value: 0.0
# Group: Picknpay
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 305 ---- value: 0.0
# Group: Sasol
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 306 ---- value: 0.0
# Group: Ssw
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 307 ---- value: 0.0
# Group: Tongaat
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 308 ---- value: 0.0
# Group: Uct1&2
# Question: Employee wages and benefits as a proportion of revenue by gender: Male
#
# idx: 309 ---- value: 0.0
# Group: Absa
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 310 ---- value: 0.0
# Group: Clicks
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 311 ---- value: 0.0
# Group: Distell
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 312 ---- value: 0.0
# Group: Impala
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 313 ---- value: 0.0
# Group: Oceana1&2
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 314 ---- value: 0.0
# Group: Picknpay
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 315 ---- value: 0.0
# Group: Sasol
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 316 ---- value: 0.0
# Group: Ssw
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 317 ---- value: 0.0
# Group: Tongaat
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 318 ---- value: 0.0
# Group: Uct1&2
# Question: Employee wages and benefits as a proportion of revenue by race
#
# idx: 319 ---- value: 0.0
# Group: Absa
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 320 ---- value: 0.0
# Group: Clicks
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 321 ---- value: 0.0
# Group: Distell
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 322 ---- value: 0.0
# Group: Impala
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 323 ---- value: 0.0
# Group: Oceana1&2
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 324 ---- value: 0.0
# Group: Picknpay
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 325 ---- value: 0.0
# Group: Sasol
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 326 ---- value: 0.0
# Group: Ssw
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 327 ---- value: 0.0
# Group: Tongaat
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 328 ---- value: 0.0
# Group: Uct1&2
# Question: Energy Efficiency (Energy consumption per net value added)
#
# idx: 329 ---- value: 0.0
# Group: Absa
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 330 ---- value: 0.0
# Group: Clicks
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 331 ---- value: 0.0
# Group: Distell
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 332 ---- value: 0.0
# Group: Impala
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 333 ---- value: 0.0
# Group: Oceana1&2
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 334 ---- value: 0.0
# Group: Picknpay
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 335 ---- value: 0.0
# Group: Sasol
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 336 ---- value: 0.0
# Group: Ssw
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 337 ---- value: 0.0
# Group: Tongaat
# Question: Energy efficiency: total direct and indirect energy consumed per ton of sugar produced
#
# idx: 338 ---- value: 0.0
# Group: Uct1&2
# Question: Energy Efficiency (Energy consumption per saleable output)
#
# idx: 339 ---- value: 0.0
# Group: Absa
# Question: Exercisable voting rights in the hands of black people
#
# idx: 340 ---- value: 0.0
# Group: Clicks
# Question: Exercisable voting rights in the hands of black people
#
# idx: 341 ---- value: 0.0
# Group: Distell
# Question: Exercisable voting rights in the hands of black people
#
# idx: 342 ---- value: 0.0
# Group: Impala
# Question: Exercisable voting rights in the hands of black people
#
# idx: 343 ---- value: 0.0
# Group: Oceana1&2
# Question: Exercisable voting rights in the hands of black people
#
# idx: 344 ---- value: 0.0
# Group: Picknpay
# Question: Exercisable voting rights in the hands of black people
#
# idx: 345 ---- value: 0.0
# Group: Sasol
# Question: Exercisable voting rights in the hands of black people
#
# idx: 346 ---- value: 0.0
# Group: Ssw
# Question: Exercisable voting rights in the hands of black people
#
# idx: 347 ---- value: 0.0
# Group: Tongaat
# Question: Exercisable voting rights in the hands of black people
#
# idx: 348 ---- value: 0.0
# Group: Uct1&2
# Question: Exercisable voting rights in the hands of black people
#
# idx: 349 ---- value: 0.0
# Group: Absa
# Question: Exercisable voting rights in the hands of black women
#
# idx: 350 ---- value: 0.0
# Group: Clicks
# Question: Exercisable voting rights in the hands of black women
#
# idx: 351 ---- value: 0.0
# Group: Distell
# Question: Exercisable voting rights in the hands of black women
#
# idx: 352 ---- value: 0.0
# Group: Impala
# Question: Exercisable voting rights in the hands of black women
#
# idx: 353 ---- value: 0.0
# Group: Oceana1&2
# Question: Exercisable voting rights in the hands of black women
#
# idx: 354 ---- value: 0.0
# Group: Picknpay
# Question: Exercisable voting rights in the hands of black women
#
# idx: 355 ---- value: 0.0
# Group: Sasol
# Question: Exercisable voting rights in the hands of black women
#
# idx: 356 ---- value: 0.0
# Group: Ssw
# Question: Exercisable voting rights in the hands of black women
#
# idx: 357 ---- value: 0.0
# Group: Tongaat
# Question: Exercisable voting rights in the hands of black women
#
# idx: 358 ---- value: 0.0
# Group: Uct1&2
# Question: Exercisable voting rights in the hands of black women
#
# idx: 359 ---- value: 0.0
# Group: Absa
# Question: Expenditure on employee training
#
# idx: 360 ---- value: 0.0
# Group: Clicks
# Question: Expenditure on employee training
#
# idx: 361 ---- value: 165
# Group: Distell
# Question: Expenditure on employee training
#
# idx: 362 ---- value: 0.0
# Group: Impala
# Question: Expenditure on employee training
#
# idx: 363 ---- value: 0.0
# Group: Oceana1&2
# Question: Expenditure on employee training
#
# idx: 364 ---- value: 0.0
# Group: Picknpay
# Question: Expenditure on employee training
#
# idx: 365 ---- value: 0.0
# Group: Sasol
# Question: Expenditure on employee training
#
# idx: 366 ---- value: 0.0
# Group: Ssw
# Question: Expenditure on employee training
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 367 ---- value: 0.0
# Group: Tongaat
# Question: Expenditure on employee training
#
# idx: 368 ---- value: 0.0
# Group: Uct1&2
# Question: Expenditure on employee training
#
# idx: 369 ---- value: 0.0
# Group: Absa
# Question: Expenditure on employee training per employee
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 370 ---- value: 0.0
# Group: Clicks
# Question: Expenditure on employee training per employee
#
# idx: 371 ---- value: 0.0
# Group: Distell
# Question: Expenditure on employee training per employee
#
# idx: 372 ---- value: 0.0
# Group: Impala
# Question: Expenditure on employee training per employee
#
# idx: 373 ---- value: 0.0
# Group: Oceana1&2
# Question: Expenditure on employee training per employee
#
# idx: 374 ---- value: 0.0
# Group: Picknpay
# Question: Expenditure on employee training per employee
#
# idx: 375 ---- value: 0.0
# Group: Sasol
# Question: Expenditure on employee training per employee
#
# idx: 376 ---- value: 0.0
# Group: Ssw
# Question: Expenditure on employee training per employee
#
# idx: 377 ---- value: 0.0
# Group: Tongaat
# Question: Expenditure on employee training per employee
#
# idx: 378 ---- value: 0.0
# Group: Uct1&2
# Question: Expenditure on employee training per employee
#
# idx: 379 ---- value: 0.0
# Group: Absa
# Question: ALL Administration expenses per income statement
#
# idx: 380 ---- value: 0.0
# Group: Clicks
# Question: ALL Administration expenses per income statement
#
# idx: 381 ---- value: 0.0
# Group: Distell
# Question: ALL Administration expenses per income statement
#
# idx: 382 ---- value: 0.0
# Group: Impala
# Question: ALL Administration expenses per income statement
#
# idx: 383 ---- value: 0.0
# Group: Oceana1&2
# Question: ALL Administration expenses per income statement
#
# idx: 384 ---- value: 0.0
# Group: Picknpay
# Question: ALL Administration expenses per income statement
#
# idx: 385 ---- value: 0.0
# Group: Sasol
# Question: ALL Administration expenses per income statement
#
# idx: 386 ---- value: 0.0
# Group: Ssw
# Question: ALL Administration expenses per income statement
#
# idx: 387 ---- value: 0.0
# Group: Tongaat
# Question: ALL Administration expenses per income statement
#
# idx: 388 ---- value: 0.0
# Group: Uct1&2
# Question: ALL Administration expenses per income statement
#
# idx: 389 ---- value: 0.0
# Group: Absa
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 390 ---- value: 0.0
# Group: Clicks
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 391 ---- value: 0.0
# Group: Distell
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 392 ---- value: 0.0
# Group: Impala
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 393 ---- value: 0.0
# Group: Oceana1&2
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 394 ---- value: 0.0
# Group: Picknpay
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 395 ---- value: 0.0
# Group: Sasol
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 396 ---- value: 0.0
# Group: Ssw
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 397 ---- value: 0.0
# Group: Tongaat
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 398 ---- value: 0.0
# Group: Uct1&2
# Question: Expenditures on employee health and safety (Total spend on occupational safety initiatives)
#
# idx: 399 ---- value: 0.0
# Group: Absa
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 400 ---- value: 0.0
# Group: Clicks
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 401 ---- value: 0.0
# Group: Distell
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 402 ---- value: 0.0
# Group: Impala
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 403 ---- value: 0.0
# Group: Oceana1&2
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 404 ---- value: 0.0
# Group: Picknpay
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 405 ---- value: 0.0
# Group: Sasol
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 406 ---- value: 0.0
# Group: Ssw
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 407 ---- value: 0.0
# Group: Tongaat
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 408 ---- value: 0.0
# Group: Uct1&2
# Question: Expenditures on employee health and safety as a proportion of revenue
#
# idx: 409 ---- value: 0.0
# Group: Absa
# Question: Fatal-injury frequency rate (number of fatalities per 200 000 person hours worked)
#
# idx: 410 ---- value: 0.0
# Group: Clicks
# Question: Fatal injury frequency rate (FIFR)
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 411 ---- value: 0.0
# Group: Distell
# Question: Fatal injury frequency rate (FIFR)
#
# idx: 412 ---- value: 0.0
# Group: Impala
# Question: FIFR
#
# idx: 413 ---- value: 0.0
# Group: Oceana1&2
# Question: Fatal injury frequency rate (FIFR)
#
# idx: 414 ---- value: 0.0
# Group: Picknpay
# Question: Fatal injury frequency rate (FIFR)
#
# idx: 415 ---- value: 0.0
# Group: Sasol
# Question: Employee and service provider fatal injury frequency rate
#
# idx: 416 ---- value: 0.0
# Group: Ssw
# Question: Fatal injury frequency rate (FIFR)
#
# idx: 417 ---- value: 0.0
# Group: Tongaat
# Question: Fatal injury frequency rate (FIFR, i.e. number of fatalities per 200 000 person hours worked) – employees and contractors
#
# idx: 418 ---- value: 0.0
# Group: Uct1&2
# Question: Fatal injury frequency rate (FIFR)
#
# idx: 419 ---- value: 0.0
# Group: Absa
# Question: Fatality rate
#
# idx: 420 ---- value: 0.0
# Group: Clicks
# Question: Fatality rate
#
# idx: 421 ---- value: 0.0
# Group: Distell
# Question: Fatality rate
#
# idx: 422 ---- value: 0.0
# Group: Impala
# Question: Fatality rate
#
# idx: 423 ---- value: 0.0
# Group: Oceana1&2
# Question: Fatality
#
# idx: 424 ---- value: 0.0
# Group: Picknpay
# Question: Fatality rate
#
# idx: 425 ---- value: 0.0
# Group: Sasol
# Question: Fatality rate
#
# idx: 426 ---- value: 0.0
# Group: Ssw
# Question: Fatality rate
#
# idx: 427 ---- value: 0.0
# Group: Tongaat
# Question: Fatality rate
#
# idx: 428 ---- value: 0.0
# Group: Uct1&2
# Question: Fatality rate
#
# idx: 429 ---- value: 0.0
# Group: Absa
# Question: Finance cost per income statement
#
# idx: 430 ---- value: 0.0
# Group: Clicks
# Question: Finance cost per income statement
#
# idx: 431 ---- value: 0.0
# Group: Distell
# Question: Finance cost per income statement
#
# idx: 432 ---- value: 0.0
# Group: Impala
# Question: Finance cost per income statement
#
# idx: 433 ---- value: 0.0
# Group: Oceana1&2
# Question: Finance cost per income statement
#
# idx: 434 ---- value: 0.0
# Group: Picknpay
# Question: Finance cost per income statement
#
# idx: 435 ---- value: 0.0
# Group: Sasol
# Question: Finance cost per income statement
#
# idx: 436 ---- value: 0.0
# Group: Ssw
# Question: Finance cost per income statement
#
# idx: 437 ---- value: 0.0
# Group: Tongaat
# Question: Finance cost per income statement
#
# idx: 438 ---- value: 0.0
# Group: Uct1&2
# Question: Finance costs
#
# idx: 439 ---- value: 0.0
# Group: Absa
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 440 ---- value: 0.0
# Group: Clicks
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 441 ---- value: 0.0
# Group: Distell
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 442 ---- value: 0.0
# Group: Impala
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 443 ---- value: 0.0
# Group: Oceana1&2
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 444 ---- value: 0.0
# Group: Picknpay
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 445 ---- value: 0.0
# Group: Sasol
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 446 ---- value: 0.0
# Group: Ssw
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 447 ---- value: 0.0
# Group: Tongaat
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 448 ---- value: 0.0
# Group: Uct1&2
# Question: Financial assistance received from the government - Total monetary value of financial assistance received by the organisation from any government during the reporting period
#
# idx: 449 ---- value: 0.0
# Group: Absa
# Question: Frequency/incident rates of occupational injuries
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 450 ---- value: 0.0
# Group: Clicks
# Question: Frequency/incident rates of occupational injuries
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 451 ---- value: 0.0
# Group: Distell
# Question: Frequency/incident rates of occupational injuries
#
# idx: 452 ---- value: 0.0
# ...
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 5006 ---- value: 0.0
# Group: Ssw
# Question: Percentage of non-hazardous waste landfilled
#
# idx: 5007 ---- value: 0.0
# Group: Tongaat
# Question: Percentage of non-hazardous waste landfilled
#
# idx: 5008 ---- value: 0.0
# Group: Uct1&2
# Question: Percentage of non-hazardous waste landfilled
#
# idx: 5009 ---- value: 0.0
# Group: Absa
# Question: Duration (days) of non-technical delays
#
# idx: 5010 ---- value: 0.0
# Group: Clicks
# Question: Duration (days) of non-technical delays
#
# idx: 5011 ---- value: 0.0
# Group: Distell
# Question: Duration (days) of non-technical delays
#
# idx: 5012 ---- value: 0.0
# Group: Impala
# Question: Duration (days) of non-technical delays
#
# idx: 5013 ---- value: 0.0
# Group: Oceana1&2
# Question: Duration (days) of non-technical delays
#
# idx: 5014 ---- value: 0.0
# Group: Picknpay
# Question: Duration (days) of non-technical delays
#
# idx: 5015 ---- value: 0.0
# Group: Sasol
# Question: Duration (days) of non-technical delays
#
# idx: 5016 ---- value: 0.0
# Group: Ssw
# Question: Duration (days) of non-technical delays
#
# idx: 5017 ---- value: 0.0
# Group: Tongaat
# Question: Duration (days) of non-technical delays
#
# idx: 5018 ---- value: 0.0
# Group: Uct1&2
# Question: Duration (days) of non-technical delays
#
# idx: 5019 ---- value: 0.0
# Group: Absa
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5020 ---- value: 0.0
# Group: Clicks
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5021 ---- value: 0.0
# Group: Distell
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5022 ---- value: 0.0
# Group: Impala
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5023 ---- value: 0.0
# Group: Oceana1&2
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5024 ---- value: 0.0
# Group: Picknpay
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5025 ---- value: 0.0
# Group: Sasol
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5026 ---- value: 0.0
# Group: Ssw
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5027 ---- value: 0.0
# Group: Tongaat
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5028 ---- value: 0.0
# Group: Uct1&2
# Question: Fines and sanctions for non-compliance with environmental regulations
#
# idx: 5029 ---- value: 0.0
# Group: Absa
# Question: Total External carbon tax paid
#
# idx: 5030 ---- value: 0.0
# Group: Clicks
# Question: Total External carbon tax paid
#
# idx: 5031 ---- value: 0.0
# Group: Distell
# Question: Rand value of carbon tax paid
#
# idx: 5032 ---- value: 3071560.65
# Group: Impala
# Question: Total External carbon tax paid
#
# idx: 5033 ---- value: 0.0
# Group: Oceana1&2
# Question: Total External carbon tax paid
#
# idx: 5034 ---- value: 0.0
# Group: Picknpay
# Question: Total External carbon tax paid
#
# idx: 5035 ---- value: 0.0
# Group: Sasol
# Question: Total External carbon tax paid
#
# idx: 5036 ---- value: 0.0
# Group: Ssw
# Question: carbon tax expense
#
# idx: 5037 ---- value: 0.0
# Group: Tongaat
# Question: Total External carbon tax paid
#
# idx: 5038 ---- value: 0.0
# Group: Uct1&2
# Question: Total External carbon tax paid
#
# idx: 5039 ---- value: 0.0
# Group: Absa
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5040 ---- value: 0.0
# Group: Clicks
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5041 ---- value: 0.0
# Group: Distell
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5042 ---- value: 0.0
# Group: Impala
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 5043 ---- value: 0.0
# Group: Oceana1&2
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# Error: 429 Resource has been exhausted (e.g. check quota).
# Error: 429 Resource has been exhausted (e.g. check quota).
# idx: 5044 ---- value: 0.0
# Group: Picknpay
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5045 ---- value: 0.0
# Group: Sasol
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5046 ---- value: 0.0
# Group: Ssw
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5047 ---- value: 0.0
# Group: Tongaat
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5048 ---- value: 0.0
# Group: Uct1&2
# Question: Discussion of processes to assess and manage risks and/or hazards associated with chemicals in products
#
# idx: 5049 ---- value: 0.0
# Group: Absa
# Question: Total carbon emissions (tonnes CO_{2} )
#
# idx: 5050 ---- value: 0.0
# Group: Clicks
# Question: Total Absolute GHG emissions (scope 1 - 3)
#
# idx: 5051 ---- value: 0.0
# Group: Distell
# Question: Total carbon emissions (tonnes of carbon dioxide equivalents, CO2 e) – Scopes 1, 2 and 3
#
# idx: 5052 ---- value: 489,251
# Group: Impala
# Question: Total Absolute GHG emissions (scope 1 - 3)
#
# idx: 5053 ---- value: 1016.0
# Group: Oceana1&2
# Question: Absolute GHG emissions (Total scope 1, 2 and outside of scopes (other direct emissions))
#
# idx: 5054 ---- value: 154,577
# Group: Picknpay
# Question: Total Absolute GHG emissions (scope 1 - 3)
#
# idx: 5055 ---- value: 0.0
# Group: Sasol
# Question: Total greenhouse gas (CO2 equivalent) (kilotons)
#
# idx: 5056 ---- value: 0.0
# Group: Ssw
# Question: Total Absolute GHG emissions (scope 1 - 3)
#
# idx: 5057 ---- value: 0.0
# Group: Tongaat
# Question: Total Absolute GHG emissions (scope 1 - 3)
#
# idx: 5058 ---- value: 0.0
# Group: Uct1&2
# Question: Total Emissions
#
# idx: 5059 ---- value: 0.0
# Group: Absa
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5060 ---- value: 0.0
# Group: Clicks
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5061 ---- value: 0.0
# Group: Distell
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5062 ---- value: 0.0
# Group: Impala
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5063 ---- value: 0.0
# Group: Oceana1&2
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5064 ---- value: 0.0
# Group: Picknpay
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5065 ---- value: 0.0
# Group: Sasol
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5066 ---- value: 0.0
# Group: Ssw
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5067 ---- value: 0.0
# Group: Tongaat
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5068 ---- value: 0.0
# Group: Uct1&2
# Question: Carbon Intensity: Average Volume of Carbon Emissions per Person Hour Worked (tonnes CO2 e/PHW)
#
# idx: 5069 ---- value: 0.0
# Group: Absa
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5070 ---- value: 0.0
# Group: Clicks
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5071 ---- value: 0.0
# Group: Distell
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5072 ---- value: 0.0
# Group: Impala
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5073 ---- value: 0.0
# Group: Oceana1&2
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5074 ---- value: 0.0
# Group: Picknpay
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5075 ---- value: 0.0
# Group: Sasol
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5076 ---- value: 0.0
# Group: Ssw
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5077 ---- value: 0.0
# Group: Tongaat
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5078 ---- value: 0.0
# Group: Uct1&2
# Question: Discussion of process to identify and manage emerging materials and chemicals of concern on product safety
#
# idx: 5079 ---- value: 0.0
# Group: Absa
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5080 ---- value: 0.0
# Group: Clicks
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5081 ---- value: 0.0
# Group: Distell
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5082 ---- value: 0.0
# Group: Impala
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5083 ---- value: 0.0
# Group: Oceana1&2
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5084 ---- value: 0.0
# Group: Picknpay
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5085 ---- value: 0.0
# Group: Sasol
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5086 ---- value: 0.0
# Group: Ssw
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5087 ---- value: 0.0
# Group: Tongaat
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5088 ---- value: 0.0
# Group: Uct1&2
# Question: Discussion of process to manage risks and opportunities associated with community rights and interests
#
# idx: 5089 ---- value: 0.0
# Group: Absa
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5090 ---- value: 0.0
# Group: Clicks
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5091 ---- value: 0.0
# Group: Distell
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5092 ---- value: 38.31
# Group: Impala
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5093 ---- value: 0.0
# Group: Oceana1&2
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5094 ---- value: 0.0
# Group: Picknpay
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5095 ---- value: 0.0
# Group: Sasol
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5096 ---- value: 0.0
# Group: Ssw
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5097 ---- value: 0.0
# Group: Tongaat
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5098 ---- value: 0.0
# Group: Uct1&2
# Question: Electricity Efficiency: Average Electricity Consumed per Person Hour Worked (kWh/PHW)
#
# idx: 5099 ---- value: 0.0
# Group: Absa
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5100 ---- value: 0.0
# Group: Clicks
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5101 ---- value: 0.0
# Group: Distell
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5102 ---- value: 0.0
# Group: Impala
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5103 ---- value: 0.0
# Group: Oceana1&2
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5104 ---- value: 0.0
# Group: Picknpay
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5105 ---- value: 0.0
# Group: Sasol
# Question: Particulates (fly ash) (kilotons)
#
# idx: 5106 ---- value: 0.0
# Group: Ssw
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5107 ---- value: 0.0
# Group: Tongaat
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5108 ---- value: 0.0
# Group: Uct1&2
# Question: Air emissions of the following pollutants: (4) particulate matter (PM10)
#
# idx: 5109 ---- value: 0.0

# %%
sub_df.to_csv("submission.csv", index=False)
